# %%
print('Add')
# Out:
# Add

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Final.csv')

# %%
data
# Out:
#         humidity  precipMM  tempC
# 0             72       0.0     18
# 1             72       0.0     19
# 2             72       0.0     18
# 3             72       0.0     18
# 4             68       0.0     20
# ...          ...       ...    ...
# 116131        28       0.0     30
# 116132        29       0.0     29
# 116133        30       0.0     27
# 116134        31       0.0     26
# 116135        32       0.0     25
#
# [116136 rows x 3 columns]

# %%
data['HeatStroke'] = 0

# %%
data
# Out:
#         humidity  precipMM  tempC  HeatStroke
# 0             72       0.0     18           0
# 1             72       0.0     19           0
# 2             72       0.0     18           0
# 3             72       0.0     18           0
# 4             68       0.0     20           0
# ...          ...       ...    ...         ...
# 116131        28       0.0     30           0
# 116132        29       0.0     29           0
# 116133        30       0.0     27           0
# 116134        31       0.0     26           0
# 116135        32       0.0     25           0
#
# [116136 rows x 4 columns]

# %%
data['HeatStroke'] = 0

# %%
humidity_condition = (data['humidity'] >= 0) & (data['humidity'] <= 30)
# precipitation_condition = (data['precipMM'] >= 0) & (data['precipMM'] <= 0) 
# precipitation_condition = data['precipMM'] == 0
temperature_condition = (data['tempC'] >= 30) & (data['tempC'] <= 50) 


data['HeatStroke'] = ( temperature_condition & humidity_condition).astype(int)
# data['HeatStroke'] = (humidity_condition & precipitation_condition & temperature_condition).astype(int)

# %%
# data

# %%
 data['HeatStroke'].value_counts()
# Out:
# HeatStroke
# 0    103072
# 1     13064
# Name: count, dtype: int64

# %%
newData = data.head(40000)
# plt.figure(figsize=(10, 6))
plt.plot(newData['HeatStroke'], color='red', alpha=0.5)
plt.plot(newData['tempC'], color='green', alpha=0.5)
plt.plot(newData['precipMM'], color='black', alpha=0.5)
plt.plot(newData['humidity'], color='yellow', alpha=0.5)

# %%
data.to_csv('D1.csv')

# %%
data
# Out:
#         humidity  precipMM  tempC  HeatStroke
# 0             72       0.0     18           0
# 1             72       0.0     19           0
# 2             72       0.0     18           0
# 3             72       0.0     18           0
# 4             68       0.0     20           0
# ...          ...       ...    ...         ...
# 116131        28       0.0     30           1
# 116132        29       0.0     29           0
# 116133        30       0.0     27           0
# 116134        31       0.0     26           0
# 116135        32       0.0     25           0
#
# [116136 rows x 4 columns]

# %%
data.columns
# Out:
# Index(['humidity', 'precipMM', 'tempC', 'HeatStroke'], dtype='object')

# %%
import matplotlib.pyplot as plt

newData = data.head(10000)
# Create a scatter plot for 'humidity'
plt.figure(figsize=(8, 6))
plt.plot(range(len(newData)), newData['humidity'], color='blue', alpha=0.5)
plt.plot(range(len(newData)), newData['tempC'], color='red', alpha=0.5)
plt.plot(range(len(newData)), newData['precipMM'], color='yellow', alpha=0.5)

plt.grid(True)
plt.tight_layout()
plt.show()
