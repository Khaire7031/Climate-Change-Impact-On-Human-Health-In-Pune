# %%
print("Data Preprocessing")
# Out:
# Data Preprocessing

# %%
import pandas as pd

# %%
data = pd.read_csv('pune.csv')

# %%
data
# Out:
#                   date_time  maxtempC  mintempC  totalSnow_cm  sunHour
# 0       2008-12-11 00:00:00        30        18           0.0     11.0  \
# 1       2008-12-11 01:00:00        30        18           0.0     11.0
# 2       2008-12-11 02:00:00        30        18           0.0     11.0
# 3       2008-12-11 03:00:00        30        18           0.0     11.0
# 4       2008-12-11 04:00:00        30        18           0.0     11.0
# ...                     ...       ...       ...           ...      ...
# 116131  2022-03-11 19:00:00        35        23           0.0     11.8
# 116132  2022-03-11 20:00:00        35        23           0.0     11.8
# 116133  2022-03-11 21:00:00        35        23           0.0     11.8
# 116134  2022-03-11 22:00:00        35        23           0.0     11.8
# 116135  2022-03-11 23:00:00        35        23           0.0     11.8
#
#         uvIndex  moon_illumination  moonrise   moonset   sunrise  ...
# ...

# %%
data.columns
# Out:
# Index(['date_time', 'maxtempC', 'mintempC', 'totalSnow_cm', 'sunHour',
#        'uvIndex', 'moon_illumination', 'moonrise', 'moonset', 'sunrise',
#        'sunset', 'DewPointC', 'FeelsLikeC', 'HeatIndexC', 'WindChillC',
#        'WindGustKmph', 'cloudcover', 'humidity', 'precipMM', 'pressure',
#        'tempC', 'visibility', 'winddirDegree', 'windspeedKmph', 'location'],
#       dtype='object')

# %%
selected_columns = ['uvIndex', 'DewPointC', 'HeatIndexC', 'cloudcover', 'humidity','precipMM','pressure','tempC','visibility','windspeedKmph']
data = data[selected_columns]

# %%
data
# Out:
#         uvIndex  DewPointC  HeatIndexC  cloudcover  humidity  precipMM
# 0             6         13          18          31        72       0.0  \
# 1             6         14          19          30        72       0.0
# 2             6         13          18          29        72       0.0
# 3             6         13          18          29        72       0.0
# 4             6         13          20          23        68       0.0
# ...         ...        ...         ...         ...       ...       ...
# 116131        7          9          28           6        28       0.0
# 116132        7          9          28           7        29       0.0
# 116133        7         11          26           9        30       0.0
# 116134        7         11          26           8        31       0.0
# 116135        7         11          25           7        32       0.0
#
#         pressure  tempC  visibility  windspeedKmph
# 0           1013     18          10              5
# ...

# %%
data.describe()
# Out:
#              uvIndex      DewPointC     HeatIndexC    cloudcover
# count  116136.000000  116136.000000  116136.000000  116136.00000  \
# mean        6.208927      15.141722      26.364383      31.43028
# std         0.921580       6.093959       4.355228      34.09457
# min         4.000000     -12.000000      11.000000       0.00000
# 25%         5.000000      10.000000      25.000000       3.00000
# 50%         6.000000      16.000000      26.000000      12.00000
# 75%         7.000000      21.000000      29.000000      66.00000
# max         8.000000      25.000000      44.000000     100.00000
#
#             humidity       precipMM       pressure          tempC
# count  116136.000000  116136.000000  116136.000000  116136.000000  \
# mean       57.646001       0.231727    1009.731522      25.304720
# std        25.316012       0.802657       3.580792       4.659629
# min         4.000000       0.000000     997.000000      11.000000
# ...

# %% [markdown]
# # uvIndexuvIndex

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data['uvIndex'])

# %%
data['uvIndex'].value_counts()
# Out:
# uvIndex
# 6    42960
# 7    33840
# 5    29160
# 8     9984
# 4      192
# Name: count, dtype: int64

# %% [markdown]
# # HeatIndexC
# Heat Index is a measure of how hot it really feels when factoring in the relative humidity at a given location.
# # DewPointC
# the temperature to which the air must cool for it to become completely saturated with waterthe temperature to which the air must cool for it to become completely saturated with water

# %% [markdown]
# # cloudcover

# %%
newData = data.head(10000)

plt.plot(newData['cloudcover'], label='Cloud Cover')
plt.plot(newData['precipMM'], label='Precipitation (mm)')

# Displaying the plot
plt.legend()
plt.show()

# %%
newData = data.tail(10000)

plt.plot(newData['cloudcover'], label='Cloud Cover')
plt.plot(newData['precipMM'], label='Precipitation (mm)')

# Displaying the plot
plt.legend()
plt.show()

# %% [markdown]
# # pressure
# For most people, atmospheric pressure within the range of 970 millibars (mb) to 1030 millibars (mb) is considered normal and comfortable. This range is roughly equivalent to 28.5 inches of mercury (inHg) to 30.4 inches of mercury (inHg). Within this range, atmospheric pressure is typically conducive to good health and well-being.For most people, atmospheric pressure within the range of 970 millibars (mb) to 1030 millibars (mb) is considered normal and comfortable. This range is roughly equivalent to 28.5 inches of mercury (inHg) to 30.4 inches of mercury (inHg). Within this range, atmospheric pressure is typically conducive to good health and well-being.

# %%
plt.plot(data['pressure'], color='red')
plt.title('Pressure Over Time')
plt.xlabel('Index')
plt.ylabel('Pressure')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
data.describe()
# Out:
#              uvIndex      DewPointC     HeatIndexC    cloudcover
# count  116136.000000  116136.000000  116136.000000  116136.00000  \
# mean        6.208927      15.141722      26.364383      31.43028
# std         0.921580       6.093959       4.355228      34.09457
# min         4.000000     -12.000000      11.000000       0.00000
# 25%         5.000000      10.000000      25.000000       3.00000
# 50%         6.000000      16.000000      26.000000      12.00000
# 75%         7.000000      21.000000      29.000000      66.00000
# max         8.000000      25.000000      44.000000     100.00000
#
#             humidity       precipMM       pressure          tempC
# count  116136.000000  116136.000000  116136.000000  116136.000000  \
# mean       57.646001       0.231727    1009.731522      25.304720
# std        25.316012       0.802657       3.580792       4.659629
# min         4.000000       0.000000     997.000000      11.000000
# ...

# %% [markdown]
# # visibility: The visibility in kilometers for that time

# %% [markdown]
# # windspeedKmph

# %%
data.describe()
# Out:
#              uvIndex      DewPointC     HeatIndexC    cloudcover
# count  116136.000000  116136.000000  116136.000000  116136.00000  \
# mean        6.208927      15.141722      26.364383      31.43028
# std         0.921580       6.093959       4.355228      34.09457
# min         4.000000     -12.000000      11.000000       0.00000
# 25%         5.000000      10.000000      25.000000       3.00000
# 50%         6.000000      16.000000      26.000000      12.00000
# 75%         7.000000      21.000000      29.000000      66.00000
# max         8.000000      25.000000      44.000000     100.00000
#
#             humidity       precipMM       pressure          tempC
# count  116136.000000  116136.000000  116136.000000  116136.000000  \
# mean       57.646001       0.231727    1009.731522      25.304720
# std        25.316012       0.802657       3.580792       4.659629
# min         4.000000       0.000000     997.000000      11.000000
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['windspeedKmph'], color='red')

plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
selected_columns = ['humidity','precipMM','tempC','windspeedKmph','HeatIndexC']
data = data[selected_columns]

# %%
data
# Out:
#         humidity  precipMM  tempC
# 0             72       0.0     18
# 1             72       0.0     19
# 2             72       0.0     18
# 3             72       0.0     18
# 4             68       0.0     20
# ...          ...       ...    ...
# 116131        28       0.0     30
# 116132        29       0.0     29
# 116133        30       0.0     27
# 116134        31       0.0     26
# 116135        32       0.0     25
#
# [116136 rows x 3 columns]

# %%
data.describe()
# Out:
#             humidity       precipMM          tempC
# count  116136.000000  116136.000000  116136.000000
# mean       57.646001       0.231727      25.304720
# std        25.316012       0.802657       4.659629
# min         4.000000       0.000000      11.000000
# 25%        36.000000       0.000000      22.000000
# 50%        58.000000       0.000000      24.000000
# 75%        82.000000       0.100000      28.000000
# max       100.000000      25.700000      43.000000

# %%
newdata = data.head(100000)
plt.plot(newdata['humidity'])
plt.plot(newdata['precipMM'])
plt.plot(newdata['tempC'])

# %%
# Selecting the first 10,000 rows
newdata = data.head(100000)

plt.figure(figsize=(20, 8))
plt.plot(newdata.index, newdata['humidity'], label='Humidity')
# plt.plot(data.index, data['precipMM'], label='Precipitation (mm)')
plt.plot(newdata.index, newdata['tempC'], label='Temperature (°C)')

# Adding labels and legend
plt.title('Weather Variables Over Time (First 10,000 Rows)')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
# Selecting the first 10,000 rows
newdata = data.head(100000)

plt.figure(figsize=(20, 8))
plt.plot(newdata.index, newdata['humidity'], label='Humidity')
plt.plot(newdata.index, newdata['precipMM'], label='Precipitation (mm)')
# plt.plot(newdata.index, newdata['tempC'], label='Temperature (°C)')

# Adding labels and legend
plt.title('Weather Variables Over Time (First 10,000 Rows)')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
# Selecting the first 10,000 rows
newdata = data.head(100000)

plt.figure(figsize=(20, 8))
# plt.plot(newdata.index, newdata['humidity'], label='Humidity')
plt.plot(newdata.index, newdata['precipMM'], label='Precipitation (mm)')
plt.plot(newdata.index, newdata['tempC'], label='Temperature (°C)')

# Adding labels and legend
plt.title('Weather Variables Over Time (First 10,000 Rows)')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()

# Displaying the plot
plt.tight_layout()
plt.show()
